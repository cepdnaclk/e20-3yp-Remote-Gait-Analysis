# %% [markdown]
# # Session 4 : Gait Analysis
# ### Time : 2025-05-31 12:31:47.132000 to 2025-05-31 12:32:29.815000
# ### Sensor ID : 601
# ### Steps : 25

# %% [markdown]
# ## Fetching Raw Data from DynamoDB

# %%
import sys
import os
from datetime import datetime

# Append app to sys.path to access modules like app.utils.dynamo
sys.path.append(os.path.abspath("../app"))

# %%
from utils.dynamo import fetch_session_data

# %%
sensor_id = 601
start_time = datetime.fromisoformat("2025-05-31T12:31:47.132000")
end_time = datetime.fromisoformat("2025-05-31T12:32:29.815000")

data = fetch_session_data(sensor_id, start_time, end_time)
print(f"📦 Retrieved {len(data)} records")
# Out:
# 📦 Retrieved 42 records

# %%
data
# Out:
# [{'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('7.62'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('147'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-8.06'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674907'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.99'),
#   'q1': Decimal('-0.06'),
#   'q2': Decimal('-0.08'),
#   'q3': Decimal('-0.06'),
#   'device_id': '601',
#   'yaw': Decimal('16.81'),
#   'gx': Decimal('10.94'),
#   'gy': Decimal('-46.44'),
#   'gz': Decimal('26.87'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('2.35'),
#   'ay': Decimal('-0.65'),
#   'az': Decimal('0.27')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-2.56'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('147'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-8.13'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674908'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.98'),
#   'q1': Decimal('0.04'),
#   'q2': Decimal('-0.17'),
#   'q3': Decimal('-0.03'),
#   'device_id': '601',
#   'yaw': Decimal('29.37'),
#   'gx': Decimal('-3.69'),
#   'gy': Decimal('-13'),
#   'gz': Decimal('-15.13'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.55'),
#   'ay': Decimal('-0.03'),
#   'az': Decimal('0.26')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-5.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('148'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('19.44'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674909'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.95'),
#   'q1': Decimal('0'),
#   'q2': Decimal('-0.23'),
#   'q3': Decimal('0.22'),
#   'device_id': '601',
#   'yaw': Decimal('6.44'),
#   'gx': Decimal('-8.69'),
#   'gy': Decimal('54.75'),
#   'gz': Decimal('-46.31'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-5.53'),
#   'ay': Decimal('0.86'),
#   'az': Decimal('2.2')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('18'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('152'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-34.31'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674910'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.89'),
#   'q1': Decimal('-0.02'),
#   'q2': Decimal('-0.39'),
#   'q3': Decimal('-0.26'),
#   'device_id': '601',
#   'yaw': Decimal('76.94'),
#   'gx': Decimal('-45.81'),
#   'gy': Decimal('-14.63'),
#   'gz': Decimal('-128.75'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('3.04'),
#   'ay': Decimal('2.05'),
#   'az': Decimal('-5.2')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-5.25'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('139'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('0'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674911'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.94'),
#   'q1': Decimal('0.05'),
#   'q2': Decimal('-0.33'),
#   'q3': Decimal('0.08'),
#   'device_id': '601',
#   'yaw': Decimal('39.88'),
#   'gx': Decimal('-1.19'),
#   'gy': Decimal('-27.87'),
#   'gz': Decimal('-10.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.24'),
#   'ay': Decimal('-0.19'),
#   'az': Decimal('-0.13')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-6.75'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('151'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('23.06'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674912'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.91'),
#   'q1': Decimal('-0.02'),
#   'q2': Decimal('-0.3'),
#   'q3': Decimal('0.27'),
#   'device_id': '601',
#   'yaw': Decimal('11.81'),
#   'gx': Decimal('14'),
#   'gy': Decimal('30.88'),
#   'gz': Decimal('-36.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-4.86'),
#   'ay': Decimal('1.04'),
#   'az': Decimal('1.69')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('13.5'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('145'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-29.75'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674913'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.9'),
#   'q1': Decimal('0'),
#   'q2': Decimal('-0.4'),
#   'q3': Decimal('-0.2'),
#   'device_id': '601',
#   'yaw': Decimal('75.5'),
#   'gx': Decimal('-76.69'),
#   'gy': Decimal('-75.56'),
#   'gz': Decimal('-111.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('4.48'),
#   'ay': Decimal('2.62'),
#   'az': Decimal('-3.12')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-2.5'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('144'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-1.37'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674914'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.97'),
#   'q1': Decimal('0.03'),
#   'q2': Decimal('-0.24'),
#   'q3': Decimal('0.04'),
#   'device_id': '601',
#   'yaw': Decimal('29.87'),
#   'gx': Decimal('2.25'),
#   'gy': Decimal('-8'),
#   'gz': Decimal('-11.31'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.07'),
#   'ay': Decimal('0.05'),
#   'az': Decimal('0.13')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-7.37'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('150'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('21.56'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674915'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.95'),
#   'q1': Decimal('0.01'),
#   'q2': Decimal('-0.21'),
#   'q3': Decimal('0.24'),
#   'device_id': '601',
#   'yaw': Decimal('2.06'),
#   'gx': Decimal('-0.19'),
#   'gy': Decimal('62.38'),
#   'gz': Decimal('-39.19'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-4.63'),
#   'ay': Decimal('0'),
#   'az': Decimal('2.06')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('20.31'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('149'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-35.81'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674916'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.91'),
#   'q1': Decimal('-0.06'),
#   'q2': Decimal('-0.28'),
#   'q3': Decimal('-0.29'),
#   'device_id': '601',
#   'yaw': Decimal('65.12'),
#   'gx': Decimal('-17.37'),
#   'gy': Decimal('-79.75'),
#   'gz': Decimal('-13.81'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('3.94'),
#   'ay': Decimal('-0.98'),
#   'az': Decimal('-2.54')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-1.94'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('152'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-3.81'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674917'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.98'),
#   'q1': Decimal('0.02'),
#   'q2': Decimal('-0.2'),
#   'q3': Decimal('0.01'),
#   'device_id': '601',
#   'yaw': Decimal('27.31'),
#   'gx': Decimal('-14.38'),
#   'gy': Decimal('-21.5'),
#   'gz': Decimal('-24.56'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.84'),
#   'ay': Decimal('0.26'),
#   'az': Decimal('-0.09')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-4.06'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('1'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('150'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('14.69'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674918'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.97'),
#   'q1': Decimal('0.01'),
#   'q2': Decimal('-0.17'),
#   'q3': Decimal('0.17'),
#   'device_id': '601',
#   'yaw': Decimal('5.12'),
#   'gx': Decimal('-6.06'),
#   'gy': Decimal('53.75'),
#   'gz': Decimal('-94.94'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.24'),
#   'ay': Decimal('-0.84'),
#   'az': Decimal('-0.57')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('18.31'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('151'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-30.88'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674919'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.9'),
#   'q1': Decimal('-0.04'),
#   'q2': Decimal('-0.37'),
#   'q3': Decimal('-0.24'),
#   'device_id': '601',
#   'yaw': Decimal('71.31'),
#   'gx': Decimal('23.75'),
#   'gy': Decimal('59.81'),
#   'gz': Decimal('93.5'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('3.2'),
#   'ay': Decimal('-2.12'),
#   'az': Decimal('-0.95')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-1'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('128'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-5.5'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674920'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.98'),
#   'q1': Decimal('0.02'),
#   'q2': Decimal('-0.2'),
#   'q3': Decimal('-0.01'),
#   'device_id': '601',
#   'yaw': Decimal('28.75'),
#   'gx': Decimal('-17.37'),
#   'gy': Decimal('-27.37'),
#   'gz': Decimal('-30.62'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-1.14'),
#   'ay': Decimal('0.07'),
#   'az': Decimal('0.47')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-5.06'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('153'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('16.12'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674921'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.96'),
#   'q1': Decimal('0.01'),
#   'q2': Decimal('-0.19'),
#   'q3': Decimal('0.19'),
#   'device_id': '601',
#   'yaw': Decimal('4.37'),
#   'gx': Decimal('-2.06'),
#   'gy': Decimal('60.88'),
#   'gz': Decimal('-95.12'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-2.89'),
#   'ay': Decimal('-1.36'),
#   'az': Decimal('0.63')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('19.75'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('154'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-32.63'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674922'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.87'),
#   'q1': Decimal('-0.02'),
#   'q2': Decimal('-0.42'),
#   'q3': Decimal('-0.25'),
#   'device_id': '601',
#   'yaw': Decimal('79.37'),
#   'gx': Decimal('30.06'),
#   'gy': Decimal('24.37'),
#   'gz': Decimal('109.37'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('6.33'),
#   'ay': Decimal('-4.38'),
#   'az': Decimal('-1.76')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-2.31'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('144'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-3.81'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674923'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.97'),
#   'q1': Decimal('0.03'),
#   'q2': Decimal('-0.26'),
#   'q3': Decimal('0.02'),
#   'device_id': '601',
#   'yaw': Decimal('34.56'),
#   'gx': Decimal('-6.81'),
#   'gy': Decimal('-16.19'),
#   'gz': Decimal('-31.31'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.58'),
#   'ay': Decimal('-0.15'),
#   'az': Decimal('-0.41')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.75'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('136'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('13.75'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674924'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.97'),
#   'q1': Decimal('0.01'),
#   'q2': Decimal('-0.2'),
#   'q3': Decimal('0.17'),
#   'device_id': '601',
#   'yaw': Decimal('9.31'),
#   'gx': Decimal('-5.31'),
#   'gy': Decimal('84.31'),
#   'gz': Decimal('-79.62'),
#   'sys_cal': Decimal('1'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-2.79'),
#   'ay': Decimal('-1.76'),
#   'az': Decimal('1.65')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('19'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('152'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-27.62'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674925'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.92'),
#   'q1': Decimal('-0.08'),
#   'q2': Decimal('-0.31'),
#   'q3': Decimal('-0.22'),
#   'device_id': '601',
#   'yaw': Decimal('60.56'),
#   'gx': Decimal('44.06'),
#   'gy': Decimal('45.25'),
#   'gz': Decimal('116.06'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('3.51'),
#   'ay': Decimal('-1.99'),
#   'az': Decimal('-0.41')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-2.12'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('159'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('3.06'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674926'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('1'),
#   'q1': Decimal('0.02'),
#   'q2': Decimal('0'),
#   'q3': Decimal('0.03'),
#   'device_id': '601',
#   'yaw': Decimal('-3.31'),
#   'gx': Decimal('7.5'),
#   'gy': Decimal('4.25'),
#   'gz': Decimal('-1.75'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-1.12'),
#   'ay': Decimal('-0.39'),
#   'az': Decimal('-0.74')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-2.12'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('138'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('0'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674927'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('1'),
#   'q1': Decimal('0.02'),
#   'q2': Decimal('-0.01'),
#   'q3': Decimal('0'),
#   'device_id': '601',
#   'yaw': Decimal('1.56'),
#   'gx': Decimal('-0.88'),
#   'gy': Decimal('0.94'),
#   'gz': Decimal('-2.12'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.67'),
#   'ay': Decimal('-0.11'),
#   'az': Decimal('0.13')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.25'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('146'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('1'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674928'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('1'),
#   'q1': Decimal('0.03'),
#   'q2': Decimal('0'),
#   'q3': Decimal('0.01'),
#   'device_id': '601',
#   'yaw': Decimal('-1.56'),
#   'gx': Decimal('-0.19'),
#   'gy': Decimal('2.19'),
#   'gz': Decimal('8.56'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.19'),
#   'ay': Decimal('-0.15'),
#   'az': Decimal('-0.08')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('17.12'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('147'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-19'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674929'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.76'),
#   'q1': Decimal('-0.22'),
#   'q2': Decimal('0.59'),
#   'q3': Decimal('-0.15'),
#   'device_id': '601',
#   'yaw': Decimal('-60.38'),
#   'gx': Decimal('-61.56'),
#   'gy': Decimal('296.37'),
#   'gz': Decimal('19.12'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.21'),
#   'ay': Decimal('0.13'),
#   'az': Decimal('-5.13')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('1.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('215'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-12.13'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674930'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.39'),
#   'q1': Decimal('-0.11'),
#   'q2': Decimal('0.89'),
#   'q3': Decimal('-0.2'),
#   'device_id': '601',
#   'yaw': Decimal('-118.81'),
#   'gx': Decimal('-1.37'),
#   'gy': Decimal('4.37'),
#   'gz': Decimal('-11.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-0.26'),
#   'ay': Decimal('0.1'),
#   'az': Decimal('0.11')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-5.69'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('145'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('12.69'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674931'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.3'),
#   'q1': Decimal('0.11'),
#   'q2': Decimal('0.93'),
#   'q3': Decimal('-0.19'),
#   'device_id': '601',
#   'yaw': Decimal('-161.5'),
#   'gx': Decimal('56.06'),
#   'gy': Decimal('41.56'),
#   'gz': Decimal('116.25'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-4.15'),
#   'ay': Decimal('1.53'),
#   'az': Decimal('2.35')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('18.5'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('160'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-33.44'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674932'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.25'),
#   'q1': Decimal('-0.33'),
#   'q2': Decimal('0.9'),
#   'q3': Decimal('-0.12'),
#   'device_id': '601',
#   'yaw': Decimal('-113.69'),
#   'gx': Decimal('-45'),
#   'gy': Decimal('-22.31'),
#   'gz': Decimal('-124.12'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('4.27'),
#   'ay': Decimal('1.31'),
#   'az': Decimal('-5.41')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.69'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('146'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-8.94'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674933'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.16'),
#   'q1': Decimal('-0.08'),
#   'q2': Decimal('0.96'),
#   'q3': Decimal('-0.23'),
#   'device_id': '601',
#   'yaw': Decimal('-150.81'),
#   'gx': Decimal('-5.44'),
#   'gy': Decimal('-3.37'),
#   'gz': Decimal('-20'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.29'),
#   'ay': Decimal('-0.19'),
#   'az': Decimal('-0.14')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-7.06'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('148'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('12.81'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674934'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.24'),
#   'q1': Decimal('0.12'),
#   'q2': Decimal('0.94'),
#   'q3': Decimal('-0.22'),
#   'device_id': '601',
#   'yaw': Decimal('-170.69'),
#   'gx': Decimal('-24.31'),
#   'gy': Decimal('126.87'),
#   'gz': Decimal('-128.12'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-1.95'),
#   'ay': Decimal('0.22'),
#   'az': Decimal('-2.74')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('22.44'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('154'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-38.5'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674935'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.31'),
#   'q1': Decimal('-0.38'),
#   'q2': Decimal('0.86'),
#   'q3': Decimal('-0.13'),
#   'device_id': '601',
#   'yaw': Decimal('-101.44'),
#   'gx': Decimal('-7.69'),
#   'gy': Decimal('-12.37'),
#   'gz': Decimal('32.06'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('5.11'),
#   'ay': Decimal('-1.47'),
#   'az': Decimal('-2.22')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-1.75'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('144'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-9.63'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674936'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.29'),
#   'q1': Decimal('-0.08'),
#   'q2': Decimal('0.93'),
#   'q3': Decimal('-0.22'),
#   'device_id': '601',
#   'yaw': Decimal('-133.75'),
#   'gx': Decimal('-15.38'),
#   'gy': Decimal('-27.31'),
#   'gz': Decimal('-30.44'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('1.89'),
#   'ay': Decimal('0'),
#   'az': Decimal('-1.04')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-4.37'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('144'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('3.87'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674937'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.23'),
#   'q1': Decimal('0.03'),
#   'q2': Decimal('0.95'),
#   'q3': Decimal('-0.21'),
#   'device_id': '601',
#   'yaw': Decimal('-157.88'),
#   'gx': Decimal('-5.56'),
#   'gy': Decimal('-34.75'),
#   'gz': Decimal('-62'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-5.22'),
#   'ay': Decimal('-0.48'),
#   'az': Decimal('1.48')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('2.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('167'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-9.69'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674938'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.33'),
#   'q1': Decimal('-0.1'),
#   'q2': Decimal('0.92'),
#   'q3': Decimal('-0.18'),
#   'device_id': '601',
#   'yaw': Decimal('-130'),
#   'gx': Decimal('99.81'),
#   'gy': Decimal('63.56'),
#   'gz': Decimal('215.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-1.24'),
#   'ay': Decimal('1.67'),
#   'az': Decimal('-0.08')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('3.81'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('155'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('64'),
#   'pitch': Decimal('-20.94'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674939'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.26'),
#   'q1': Decimal('-0.19'),
#   'q2': Decimal('0.93'),
#   'q3': Decimal('-0.2'),
#   'device_id': '601',
#   'yaw': Decimal('-124.56'),
#   'gx': Decimal('-42.25'),
#   'gy': Decimal('-43.31'),
#   'gz': Decimal('-68'),
#   'sys_cal': Decimal('2'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('3.03'),
#   'ay': Decimal('2.69'),
#   'az': Decimal('-1.59')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.5'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('148'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-4.62'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674940'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.18'),
#   'q1': Decimal('-0.04'),
#   'q2': Decimal('0.96'),
#   'q3': Decimal('-0.22'),
#   'device_id': '601',
#   'yaw': Decimal('-153.44'),
#   'gx': Decimal('-6.44'),
#   'gy': Decimal('-19.12'),
#   'gz': Decimal('-31.19'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.5'),
#   'ay': Decimal('0.23'),
#   'az': Decimal('0.57')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-4.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('148'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('9.75'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674941'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.22'),
#   'q1': Decimal('0.08'),
#   'q2': Decimal('0.95'),
#   'q3': Decimal('-0.21'),
#   'device_id': '601',
#   'yaw': Decimal('-167.06'),
#   'gx': Decimal('67.75'),
#   'gy': Decimal('28.12'),
#   'gz': Decimal('209'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('-5.91'),
#   'ay': Decimal('3.64'),
#   'az': Decimal('1.89')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('10.06'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('155'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-28.38'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674942'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.19'),
#   'q1': Decimal('-0.26'),
#   'q2': Decimal('0.94'),
#   'q3': Decimal('-0.15'),
#   'device_id': '601',
#   'yaw': Decimal('-125.69'),
#   'gx': Decimal('-40.12'),
#   'gy': Decimal('-88.94'),
#   'gz': Decimal('-108.81'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('4.38'),
#   'ay': Decimal('2.16'),
#   'az': Decimal('-1.88')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.69'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('147'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-4.94'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674943'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.21'),
#   'q1': Decimal('-0.04'),
#   'q2': Decimal('0.95'),
#   'q3': Decimal('-0.22'),
#   'device_id': '601',
#   'yaw': Decimal('-149.12'),
#   'gx': Decimal('-2.62'),
#   'gy': Decimal('-38.56'),
#   'gz': Decimal('-15.56'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('2.07'),
#   'ay': Decimal('-0.36'),
#   'az': Decimal('-1.23')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-5.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('236'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('11.19'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674945'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.25'),
#   'q1': Decimal('0.1'),
#   'q2': Decimal('0.94'),
#   'q3': Decimal('-0.21'),
#   'device_id': '601',
#   'yaw': Decimal('-165.25'),
#   'gx': Decimal('-19.44'),
#   'gy': Decimal('77.12'),
#   'gz': Decimal('-154.69'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.3'),
#   'ay': Decimal('1.04'),
#   'az': Decimal('-1.88')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('18.37'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('229'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-29.19'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674946'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.34'),
#   'q1': Decimal('-0.3'),
#   'q2': Decimal('0.88'),
#   'q3': Decimal('-0.13'),
#   'device_id': '601',
#   'yaw': Decimal('-108.25'),
#   'gx': Decimal('79.25'),
#   'gy': Decimal('26.62'),
#   'gz': Decimal('115.56'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('1.18'),
#   'ay': Decimal('-1.85'),
#   'az': Decimal('-0.47')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.87'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('172'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-6.87'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674947'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.41'),
#   'q1': Decimal('-0.05'),
#   'q2': Decimal('0.88'),
#   'q3': Decimal('-0.23'),
#   'device_id': '601',
#   'yaw': Decimal('-123.19'),
#   'gx': Decimal('-9.81'),
#   'gy': Decimal('-11.88'),
#   'gz': Decimal('-25.37'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('1.47'),
#   'ay': Decimal('-0.15'),
#   'az': Decimal('-0.42')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-6.37'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('165'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('11'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674948'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.6'),
#   'q1': Decimal('0.1'),
#   'q2': Decimal('0.78'),
#   'q3': Decimal('-0.14'),
#   'device_id': '601',
#   'yaw': Decimal('-119.69'),
#   'gx': Decimal('2.62'),
#   'gy': Decimal('-69.81'),
#   'gz': Decimal('22.06'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.06'),
#   'ay': Decimal('4.5'),
#   'az': Decimal('-0.71')},
#  {'gyro_cal': Decimal('3'),
#   'mag_cal': Decimal('3'),
#   'roll': Decimal('-3.06'),
#   'type': 'sensor_data',
#   'FSR_12': Decimal('0'),
#   'FSR_11': Decimal('0'),
#   'FSR_10': Decimal('0'),
#   'FSR_16': Decimal('0'),
#   'FSR_15': Decimal('143'),
#   'FSR_1': Decimal('0'),
#   'FSR_14': Decimal('4095'),
#   'FSR_13': Decimal('0'),
#   'FSR_3': Decimal('0'),
#   'FSR_2': Decimal('0'),
#   'FSR_5': Decimal('0'),
#   'FSR_4': Decimal('0'),
#   'pitch': Decimal('-0.37'),
#   'FSR_7': Decimal('0'),
#   'FSR_6': Decimal('0'),
#   'FSR_9': Decimal('0'),
#   'timestamp': Decimal('1748674949'),
#   'FSR_8': Decimal('0'),
#   'q0': Decimal('0.61'),
#   'q1': Decimal('0.01'),
#   'q2': Decimal('0.77'),
#   'q3': Decimal('-0.17'),
#   'device_id': '601',
#   'yaw': Decimal('-103.81'),
#   'gx': Decimal('-5.37'),
#   'gy': Decimal('-5'),
#   'gz': Decimal('3.62'),
#   'sys_cal': Decimal('3'),
#   'accel_cal': Decimal('3'),
#   'ax': Decimal('0.14'),
#   'ay': Decimal('-0.05'),
#   'az': Decimal('0.16')}]

# %% [markdown]
# ## Step 1 :  Preprocess and Sort

# %% [markdown]
# ### Sort By Timestamp

# %%
import pandas as pd
from decimal import Decimal

# Convert to DataFrame
df = pd.json_normalize(data)

# Convert all Decimal values to float (optional but useful)
df = df.map(lambda x: float(x) if isinstance(x, Decimal) else x)

# Sort by timestamp
df = df.sort_values(by="timestamp").reset_index(drop=True)

# Show first few rows
df.head()
# Out:
#    gyro_cal  mag_cal   roll         type  FSR_12  FSR_11  FSR_10  FSR_16  \
# 0       3.0      3.0   7.62  sensor_data     0.0     0.0     0.0     0.0
# 1       3.0      3.0  -2.56  sensor_data     0.0     0.0     0.0     0.0
# 2       3.0      3.0  -5.87  sensor_data     0.0     0.0     0.0     0.0
# 3       3.0      3.0  18.00  sensor_data     0.0     0.0     0.0     0.0
# 4       3.0      3.0  -5.25  sensor_data     0.0     0.0     0.0     0.0
#
#    FSR_15  FSR_1  ...  device_id    yaw     gx     gy      gz  sys_cal  \
# 0   147.0    0.0  ...        601  16.81  10.94 -46.44   26.87      3.0
# 1   147.0    0.0  ...        601  29.37  -3.69 -13.00  -15.13      3.0
# 2   148.0    0.0  ...        601   6.44  -8.69  54.75  -46.31      3.0
# 3   152.0    0.0  ...        601  76.94 -45.81 -14.63 -128.75      3.0
# 4   139.0    0.0  ...        601  39.88  -1.19 -27.87  -10.69      3.0
#
#    accel_cal    ax    ay    az
# 0        3.0  2.35 -0.65  0.27
# 1        3.0 -0.55 -0.03  0.26
# 2        3.0 -5.53  0.86  2.20
# 3        3.0  3.04  2.05 -5.20
# 4        3.0 -0.24 -0.19 -0.13
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Check for Missing FSR Values

# %%
required_fsrs = [f"FSR_{i}" for i in range(1, 17)]
missing = [col for col in required_fsrs if col not in df.columns]
print("Missing FSR columns:", missing)
# Out:
# Missing FSR columns: []

# %% [markdown]
# ### Clipping FSR values (0 to 4095)

# %%
for col in required_fsrs:
    df[col] = df[col].clip(0, 4095)

# %% [markdown]
# ### Normalizing  Timestamps

# %%
df["time_sec"] = df["timestamp"] - df["timestamp"].min()
